# %% [markdown]
# Preparing Dataset

# %%
python bench/prepare_dataset.py
# Out:
# Created temporary workspace at /tmp/aibrix-benchmark
# No dataset file specified, downloading dataset to /tmp/aibrix-benchmark/dataset/raw
# ...
# Dataset downloaded to /tmp/aibrix-benchmark/dataset/raw/ShareGPT_V3_unfiltered_cleaned_split.json
# Setup complete!

# %% [markdown]
# ### Download ShareGPT Dataset
# This cell downloads the ShareGPT dataset from Hugging Face and saves it to `./dataset/raw` using the provided script.

# %%
# !python bench/download_sharegpt.py --outdir ./dataset/raw
# Out:
# python: can't open file '/Users/venkat/Documents/p/venkat-github/aibrix/benchmarks/plot/aibrix0.3-routing/vtc-basic/bench/download_sharegpt.py': [Errno 2] No such file or directory
